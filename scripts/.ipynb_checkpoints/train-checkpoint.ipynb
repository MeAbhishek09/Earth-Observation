# %%
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report

SAVE_DIR = "../Dataset/processed"

X_train = np.load(os.path.join(SAVE_DIR, "X_train.npy"))
X_test  = np.load(os.path.join(SAVE_DIR, "X_test.npy"))
y_train = np.load(os.path.join(SAVE_DIR, "y_train.npy"))
y_test  = np.load(os.path.join(SAVE_DIR, "y_test.npy"))

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (4809, 128, 128, 3)
# Test shape: (3206, 128, 128, 3)

# %%
#  NORMALIZATION
X_train = X_train.astype("float32") / 255.0
X_test  = X_test.astype("float32") / 255.0

# %%
def build_cnn(input_shape=(128,128,3), num_classes=None):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, 3, activation='relu', input_shape=input_shape),
        tf.keras.layers.MaxPooling2D(),

        tf.keras.layers.Conv2D(64, 3, activation='relu'),
        tf.keras.layers.MaxPooling2D(),

        tf.keras.layers.Conv2D(128, 3, activation='relu'),
        tf.keras.layers.GlobalAveragePooling2D(),

        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
num_classes = len(np.unique(y_train))

model = build_cnn(
    input_shape=X_train.shape[1:],
    num_classes=num_classes
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  global_average_pooling2d (G  (None, 128)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 7)                 903
#
# ...
# Total params: 110,663
# Trainable params: 110,663
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/10
# 136/136 [==============================] - 22s 44ms/step - loss: 0.9675 - accuracy: 0.6788 - val_loss: 0.8413 - val_accuracy: 0.6861
# Epoch 2/10
# 136/136 [==============================] - 5s 36ms/step - loss: 0.7381 - accuracy: 0.7470 - val_loss: 0.6230 - val_accuracy: 0.7859
# Epoch 3/10
# 136/136 [==============================] - 5s 37ms/step - loss: 0.6099 - accuracy: 0.8013 - val_loss: 0.6308 - val_accuracy: 0.7900
# Epoch 4/10
# 136/136 [==============================] - 5s 36ms/step - loss: 0.5676 - accuracy: 0.8207 - val_loss: 0.4699 - val_accuracy: 0.8462
# Epoch 5/10
# 136/136 [==============================] - 5s 35ms/step - loss: 0.4944 - accuracy: 0.8396 - val_loss: 0.4466 - val_accuracy: 0.8565
# Epoch 6/10
# 136/136 [==============================] - 5s 35ms/step - loss: 0.4901 - accuracy: 0.8364 - val_loss: 0.4458 - val_accuracy: 0.8586
# Epoch 7/10
# ...

# %%
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 101/101 [==============================] - 2s 13ms/step

# %%
print("Unique y_test:", sorted(set(y_test)))
print("Unique y_pred:", sorted(set(y_pred)))
# Out:
# Unique y_test: [0, 1, 2, 3, 4, 5, 6]
# Unique y_pred: [0, 1, 3, 6]

# %%
with open(os.path.join(SAVE_DIR, "label_map.json")) as f:
    label_map = json.load(f)

print(label_map)
# Out:
# {'0': 'Built-up', '1': 'Cropland', '2': 'Grassland', '3': 'Shrubland', '4': 'Water', '5': 'Wetland', '6': 'tree'}

# %%
from sklearn.metrics import accuracy_score, f1_score

acc = accuracy_score(y_test, y_pred)
f1  = f1_score(y_test, y_pred, average='weighted')

print("Test Accuracy:", acc)
print("Weighted F1-score:", f1)
# Out:
# Test Accuracy: 0.8702432938240798
# Weighted F1-score: 0.8468065477162318

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(4,4))
plt.imshow(cm, cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

# show numbers inside cells
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, cm[i, j], ha="center", va="center")

plt.tight_layout()
plt.show()

# %%
model.save("../models/landuse_cnn_model.keras")
print("Model saved")
# Out:
# Model saved

# %% [raw]
# Interpretation:
# The confusion matrix shows that the model correctly classifies many samples of class 0 and class 1, as seen from the large values on the diagonal (604 and 2115). However, there are noticeable misclassifications, especially between class 0 and class 1 and for other classes where diagonal values are very low or zero. This indicates the model performs well for the major classes but struggles to correctly identify several minority classes
